# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielCataneo/Pyhton_DataBasics/blob/main/Pandas/Desafio_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# 1)
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df = pd.read_csv(url)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# Desafio 1
#
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.

# %%
# 2)
df.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
# 3)
df.shape
# Out:
# (18, 4)

# %%
# 4)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %% [markdown]
# Desafio 2
#
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
# 1)
df.isnull().sum()
df.fillna(0, inplace=True)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
# Selecionando os index
notas_remover = df.query('Notas == 0').index

# Removendo as colunas com null
df.drop(notas_remover, axis=0, inplace=True)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
# 2)
# Selecionado os index
index_aluno = df.query('Nome == "Alice" or Nome == "Carlos"').index

# Removendo os registros
df.drop(index_aluno, axis=0, inplace=True)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
# 3)
Aprovados = df.query('Aprovado == True')
Aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
# 4)
Aprovados.to_csv('alunos_aprovados.csv', sep=';',index=False)

# %%
# extra.: Substituir as notas 7 por 8
df.replace(7, 8, inplace=True)
df
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4    Danielly     21   10.0      True
# 6        Dara     21    8.0      True
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# Desafio 3
#
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.
#
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.
#
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df['Pontos_extras'] = df['Notas'] * 0.4
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True            3.0
# 2       Cátia     27    2.5     False            1.0
# 3       Denis     18    5.0     False            2.0
# 4    Danielly     21   10.0      True            4.0
# 6        Dara     21    8.0      True            3.2
# 11       Igor     24    4.5     False            1.8
# 12  Sthefanie     26    9.5      True            3.8
# 13      Mirla     25    9.0      True            3.6
# 15     Mylena     29    8.0      True            3.2
# 17      Nadia     34    8.0      True            3.2

# %%
df['Notas_Finais'] = df['Notas' ] + df['Pontos_extras']
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais
# 0         Ary     20    7.5      True            3.0          10.5
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4    Danielly     21   10.0      True            4.0          14.0
# 6        Dara     21    8.0      True            3.2          11.2
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 15     Mylena     29    8.0      True            3.2          11.2
# 17      Nadia     34    8.0      True            3.2          11.2

# %%
df['Aprovacao_Final'] = df['Notas_Finais'].apply(lambda x : True if x >= 6 else False)
df
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_Finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4    Danielly     21   10.0      True            4.0          14.0
# 6        Dara     21    8.0      True            3.2          11.2
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 15     Mylena     29    8.0      True            3.2          11.2
# 17      Nadia     34    8.0      True            3.2          11.2
#
#     Aprovacao_Final
# 0              True
# 2             False
# 3              True
# 4              True
# 6              True
# 11             True
# 12             True
# 13             True
# 15             True
# 17             True

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
df_2 = pd.read_csv(url, sep=';')
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %% [markdown]
# Desafio 3
#
# 1) Calcular a média de quartos por apartamento;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
# 1)

# Escolhe somente os apartamentos e tira a média dos quartos
df_2.query('Tipo == "Apartamento"')['Quartos'].mean()
# Out:
# np.float64(2.481568707761622)

# %%
# 2)

# nunique = unique , só que retorna um numero ao invés da lista
df_2['Bairro'].nunique()
# Out:
# 162

# %%
# 3)

# Agrupa por bairro e tira uma média da coluna valor
df_2.groupby('Bairro')['Valor'].mean().sort_values(ascending=False)
# Out:
# Bairro
# Jacarepaguá         314143.489637
# Irajá               154610.470588
# Caju                120264.782609
# Vasco da Gama       120000.000000
# Cidade Nova          88166.692308
#                         ...
# Inhoaíba               738.888889
# Turiaçu                733.333333
# Magalhães Bastos       726.666667
# Santíssimo             709.090909
# Senador Camará         635.000000
# Name: Valor, Length: 162, dtype: float64

# %%
# 4)
cinco_maiores = df_2.groupby('Bairro')['Valor'].mean().sort_values(ascending=False).head()
cinco_maiores.plot(kind='barh', figsize=(14, 10), color ='purple')
# Out:
# <Axes: ylabel='Bairro'>

# %%
dados = pd.DataFrame([['Feira', 'Cebola', 2.5],
                        ['Mercado', 'Cebola', 1.99],
                        ['Supermercado', 'Cebola', 1.69],
                        ['Feira', 'Tomate', 4],
                        ['Mercado', 'Tomate', 3.29],
                        ['Supermercado', 'Tomate', 2.99],
                        ['Feira', 'Batata', 4.2],
                        ['Mercado', 'Batata', 3.99],
                        ['Supermercado', 'Batata', 3.69]],
                        columns = ['Local', 'Produto', 'Preço'])
dados
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
# Excluindo somente o supermercado
d2 = dados.query('Local == "Supermercado"').index

dados.drop(d2,axis=0, inplace=True)
dados
# Out:
#      Local Produto  Preço
# 0    Feira  Cebola   2.50
# 1  Mercado  Cebola   1.99
# 3    Feira  Tomate   4.00
# 4  Mercado  Tomate   3.29
# 6    Feira  Batata   4.20
# 7  Mercado  Batata   3.99
