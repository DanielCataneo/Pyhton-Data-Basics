# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielCataneo/Pyhton_DataBasics/blob/main/Pandas/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';') # sep = delimitador
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
# Para o topo
dados.head(10)

# Para o final
dados.tail(10)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %% [markdown]
# Explorando as Caracteristicas do Data Frame

# %%
# Design do DataFrame
dados.shape
# Out:
# (32960, 9)

# %%
# Nomes das colunas
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
# Info mais detalhadas
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
# Analisando somente quartos e valor
dados[['Quartos','Valor']]
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %%
# Procurando os Valores medio por tipo de imóvel
dados[['Tipo','Valor']].groupby('Tipo').mean().sort_values(by='Valor', ascending=False)
# Out:
#                                      Valor
# Tipo
# Prédio Inteiro               498637.239203
# Indústria                    120000.000000
# Galpão/Depósito/Armazém       53407.062600
# Terreno Padrão                32567.714286
# Hotel                         25000.000000
# Loteamento/Condomínio         22000.000000
# Conjunto Comercial/Sala       14715.045521
# Casa Comercial                14478.264151
# Loja/Salão                    13769.646770
# Sítio                         12499.000000
# Casa de Condomínio            11952.061245
# Loja Shopping/ Ct Comercial    8126.178862
# Casa                           6793.454922
# Chácara                        4900.000000
# Apartamento                    4744.614648
# Flat                           4546.189076
# Loft                           2557.882353
# Studio                         2400.000000
# Box/Garagem                    1899.756098
# Casa de Vila                   1574.369478
# Pousada/Chalé                  1480.000000
# ...

# %%
dadosGrafico_Preco_tipo = dados[['Tipo','Valor']].groupby('Tipo').mean().sort_values(by='Valor')
dadosGrafico_Preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Removendo os Imóveis comerciais

# %%
# Pega todos os valores unicos dentro de uma coluna DISTINCT
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
# Criando lista com imóveis não residenciais
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
# Pegando somente os imoveis comerciais
dados.query('@imoveis_comerciais in Tipo')
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
# Agora utilizando not in para selecionar somente os imóveis residenciais
df = dados.query('Tipo not in @imoveis_comerciais') # ou dados.query('@imoveis_comerciais not in Tipo')
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
# Verificando se os dados estao corretos
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
# Plotando o mesmo gráfico
dadosGrafico_Preco_tipo = df[['Tipo','Valor']].groupby('Tipo').mean().sort_values(by='Valor')
dadosGrafico_Preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# Qual o Percentual de Cada tipo de imóvel na nossa base de dados ?

# %%
# Utilizando value_counts para observar a quantidade COUNT(*)

# Normalize para o valor em proporção
df['Tipo'].value_counts(normalize=True).sort_values()
# Out:
# Tipo
# Studio                0.000173
# Loft                  0.002207
# Casa de Vila          0.010774
# Flat                  0.020596
# Quitinete             0.036173
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Apartamento           0.845139
# Name: proportion, dtype: float64

# %%
# Plotando um gráfico
df_porcentagem = df['Tipo'].value_counts(normalize=True).sort_values()


df_porcentagem.plot(kind='bar', figsize=(14, 10), color ='green', edgecolor='black',
                        xlabel = 'Tipos', ylabel = 'Percentual');

# %% [markdown]
# Selecionando apenas os imóveis do tipo apartamento

# %%
# Utilizando query para filtrar
df = df.query('Tipo == "Apartamento"')
df
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %% [markdown]
# Tratando dados nulos

# %%
df.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            9
# Condominio    1865
# IPTU          6879
# dtype: int64

# %%
# fillna para substituir os dados nulos com algum valor
df = df.fillna(0)

# .dropna() para remover colunas com valores nulos
# .interpolate() para preencher os nulos com os valores vizinhos

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# Removendo registros

# %%
df.query('Condominio == 0 | Valor == 0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
# Selecionando os index para deletar depois
index_remover = df.query('Condominio == 0 | Valor == 0').index
# Out:
# Index([    5,    10,    76,   113,   166,   194,   258,   265,   275,   292,
#        ...
#        32420, 32438, 32480, 32538, 32584, 32609, 32643, 32666, 32708, 32809],
#       dtype='int64', length=752)

# %%
# Metodos para remover dados
df.drop(index_remover, axis=0, inplace=True)

# axis 0,1 colunas (0) ou linhas (1)
# Inplace para já aplicar no dataframe

# %%
df.query('Condominio == 0 | Valor == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
# Excluindo colunas Tipo
df.drop('Tipo', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-93f1a95ad418> in <cell line: 0>()
#       1 # Excluindo colunas Tipo
# ----> 2 df.drop('Tipo', axis=1, inplace=True)
#       3 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                    Centro        1      0       0    15   800.0       390.0
# 4              Higienópolis        1      0       0    48   800.0       230.0
# 6                  Cachambi        2      0       0    50  1300.0       301.0
# 11                   Grajaú        2      1       0    70  1500.0       642.0
# 12      Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 32951        Vila Valqueire        2      0       0    52  1000.0       550.0
# 32953                 Méier        2      0       0    70   900.0       490.0
# 32956           Jacarepaguá        3      1       2    78  1800.0       800.0
# 32957  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 32958                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 3      20.0
# ...

# %%
dados = pd.DataFrame([['Feira', 'Cebola', 2.5],
                        ['Mercado', 'Cebola', 1.99],
                        ['Supermercado', 'Cebola', 1.69],
                        ['Feira', 'Tomate', 4],
                        ['Mercado', 'Tomate', 3.29],
                        ['Supermercado', 'Tomate', 2.99],
                        ['Feira', 'Batata', 4.2],
                        ['Mercado', 'Batata', 3.99],
                        ['Supermercado', 'Batata', 3.69]],
                        columns = ['Local', 'Produto', 'Preço'])
dados
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
# Excluindo somente o supermercado
d2 = dados.query('Local == "Supermercado"').index
d2

dados.drop(d2,axis=0, inplace=True)
dados
# Out:
#      Local Produto  Preço
# 0    Feira  Cebola   2.50
# 1  Mercado  Cebola   1.99
# 3    Feira  Tomate   4.00
# 4  Mercado  Tomate   3.29
# 6    Feira  Batata   4.20
# 7  Mercado  Batata   3.99

# %% [markdown]
# Aplicando Filtros

# %%
selecao1 = df['Quartos'] == 1
df[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
# Unindo as duas selecoes
selecao_final = selecao1 & selecao2
df[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
# Salvando em outra variável
df_1 = df[selecao_final]

# %% [markdown]
# Apartamentos com 2 quartos, aluguel < R$ 3000 e área > 70 metros quadrados

# %%
selecao_3 = (df['Quartos'] == 2) & (df['Valor'] < 3000) & (df['Area'] > 70)
df[selecao_3]
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 57     Recreio dos Bandeirantes        2      1       2    83  1600.0
# 67                     Maracanã        2      0       0    86  1800.0
# ...                         ...      ...    ...     ...   ...     ...
# 32881                   Taquara        2      1       1    71  1300.0
# 32890   Freguesia (Jacarepaguá)        2      1       1    87  1300.0
# 32933  Recreio dos Bandeirantes        2      1       1   105  2100.0
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
#
#        Condominio   IPTU
# 21          700.0  138.0
# 24          700.0    0.0
# 32          740.0    0.0
# ...

# %%
df_2 = df[selecao_3]
df_2
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 57     Recreio dos Bandeirantes        2      1       2    83  1600.0
# 67                     Maracanã        2      0       0    86  1800.0
# ...                         ...      ...    ...     ...   ...     ...
# 32881                   Taquara        2      1       1    71  1300.0
# 32890   Freguesia (Jacarepaguá)        2      1       1    87  1300.0
# 32933  Recreio dos Bandeirantes        2      1       1   105  2100.0
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
#
#        Condominio   IPTU
# 21          700.0  138.0
# 24          700.0    0.0
# 32          740.0    0.0
# ...

# %% [markdown]
# Salvando os Dados

# %%
df.to_csv('aluguel_residencial.csv', index=False,sep=';') # Index=False para não dar problema no arquivo

# %%
pd.read_csv('aluguel_residencial.csv', sep=';')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %% [markdown]
# Criando Colunas numericas

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
df = pd.read_csv(url, sep=';')

# %%
# Valor total gasto por mês
df['Valor_por_mes'] = df['Valor'] + df['Condominio']
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
df['Valor_por_ano'] = df['Valor_por_mes'] * 12 + df['IPTU']
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %% [markdown]
# Criando uma coluna categórica

# %%
df['Descricao'] = df['Tipo'] + ' em ' + df['Bairro']
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
df['Descricao'] = df['Tipo'] + ' em ' + df['Bairro'] + ' com ' + \
                                        df['Quartos'].astype(str) + ' quarto(s) ' + \
                                        ' e ' + df['Vagas'].astype(str) + ' vaga(s) de garagem.'

df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %% [markdown]
# Criando uma Coluna Binária

# %%
df['Possui_Suite'] = df['Suites'].apply(lambda x: 'Sim' if x > 0 else 'Não')
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
df.to_csv('dados_completos.csv', index=False,sep=';')
